# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_psp_data():
    """
    This function loads in parker solar probe data during a close approach
    Prepares and interpolates the data to match coronal model spatial resolution
    """

def load_coronal_model_data():
    """
    This function accesses coronal solution at relevant time window of psp data, generates a windspeed slice along the path
    of psp orbit w.r.t position above the sun. 

    Will probably have to do some kind of funky coordinate transformations + interpolation
    """

# %%
# Load model and PSP data
# model_data = load_coronal_model_data()  # Function to load model (MAS) data at 30 solar radii
# psp_data = load_psp_data()  # Function to load PSP data

# Example placeholder data
model_time = np.linspace(0, 10, 100)  # Replace with actual model time array
model_wind_speed = np.random.normal(400, 20, 100)  # Replace with actual model wind speeds

psp_time = np.linspace(0, 10, 100)  # Replace with actual PSP time array
psp_wind_speed = np.random.normal(410, 25, 100)  # Replace with actual PSP wind speeds

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(model_time, model_wind_speed, label='Coronal Model at 30 Solar Radii')
plt.plot(psp_time, psp_wind_speed, label='Parker Solar Probe Data')
plt.xlabel('Time [UTC]')
plt.ylabel('Wind Speed (km/s)')
plt.title('Comparison of Solar Wind Speed')
plt.legend(frameon = False)
plt.show()

# Statistical Analysis
correlation = np.corrcoef(model_wind_speed, psp_wind_speed)[0, 1]
mae = np.mean(np.abs(model_wind_speed - psp_wind_speed))
rmse = np.sqrt(np.mean((model_wind_speed - psp_wind_speed)**2))

print(f'Correlation: {correlation}')
print(f'Mean Absolute Error: {mae}')
print(f'Root Mean Square Error: {rmse}')
# Out:
# Correlation: 0.031738899781188566
# Mean Absolute Error: 24.90514324286469
# Root Mean Square Error: 33.33044276089557
